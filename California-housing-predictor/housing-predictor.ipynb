# %% [markdown]
# ## Importacion de dataset

# %% [markdown]
# ## Particionar dataset en train, val y test
#
# - Proporciones en 80/10/10

# %% [markdown]
# ## Preprocesamiento
# - Eliminar outliers en todas las caracteristicas excepto "Latitude" y "Longitude"
# - Aplicar standard scaling a todas las caracteristicas excepto "Latitude" y "Longitude"
# - Utilizar "Latitude" y "Longitude"

# %% [markdown]
# ## Creacion y entrenamiento de red neuronal
# - Utilizar 3 modelos distintos
# - Utilizando diferentes hiperparametros en cada uno
# - Evaluacion del modelo
