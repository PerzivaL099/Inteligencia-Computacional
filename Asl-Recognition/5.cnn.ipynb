# %% [markdown]
# # ASL Recognition with CNNs
#
# This notebook implements a Convolutional Neural Network (CNN) for recognizing American Sign Language (ASL) gestures. We will compare the performance of a Fully Connected Neural Network (FCNN) with that of a CNN on the ASL dataset.
#
# For more information on the ASL alphabet, you can refer to this site: https://www.asl.gs/

# %%
import random

import torch.nn as nn
import pandas as pd
import torch
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.is_available()
# Out:
# False

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

data_base_path = "./" if IN_COLAB else "./"

# %% [markdown]
# ### Load data
#
# The data for the ASL dataset is stored in CSV files. It is already split into training, validation, and test sets. Each row in the CSV files contains pixel values for a 28x28 image (flattened into a single row) and a label indicating the ASL gesture.
#
# The labels are integers from 0 to 23, corresponding to the letters A-Z (J and Z are excluded because they require movement).
#
# The images are grayscale, so each pixel value ranges from 0 to 255.

# %%
train_df = pd.read_csv(data_base_path + "train.csv")
val_df = pd.read_csv(data_base_path + "val.csv")
test_df = pd.read_csv(data_base_path + "test.csv")

# %%
def label_to_letter(lbl):
    letter_code = ord('A') + int(lbl)
    return chr(letter_code) if letter_code < ord('J') else chr(letter_code + 1)

def show(img, lbl):
    i = img.reshape(28,28)
    plt.figure(figsize=(5,5))
    plt.title(label_to_letter(lbl), fontdict={'fontsize': 30})
    plt.axis('off')
    plt.imshow(i, cmap='gray')

# %%
rnd_idx = random.choice(train_df.index)
image = train_df.iloc[rnd_idx].drop('label').values
label = train_df.iloc[rnd_idx]['label']
show(image, label)

# %% [markdown]
# ## Preparing dataset
#
# Let's start by creating the custom Dataset class for our ASL data. This class will take a DataFrame as input and will return the image and label for each sample. We will also normalize the pixel values to be between 0 and 1. The images will be reshaped as a 28x28 tensor with a single channel (grayscale).

# %%
IMG_HEIGHT = 28
IMG_WIDTH = 28
IMG_CHANNELS = 1

class AslDataset(Dataset):
    def __init__(self, base_df):
        x_df = base_df.copy()
        y_df = x_df.pop('label')
        x_df = x_df.values / 255
        x_df = x_df.reshape(-1, IMG_CHANNELS, IMG_WIDTH, IMG_HEIGHT)
        self.xs = torch.tensor(x_df).float().to(device)
        self.ys = torch.tensor(y_df).long().to(device)

    def __getitem__(self, idx):
        x = self.xs[idx]
        y = self.ys[idx]
        return x, y

    def __len__(self):
        return len(self.xs)

# %%
train_data = AslDataset(train_df)
val_data = AslDataset(val_df)
test_data = AslDataset(test_df)

# %%
batch_size = 32

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Training functions
#
# Now we can define our training functions. Since we will use accuracy to evaluate our model, we will create a function to calculate accuracy as well.

# %%
def get_batch_accuracy(output, y, N):
    pred = output.argmax(dim=1, keepdim=True)
    correct = pred.eq(y.view_as(pred)).sum().item()
    return correct / N

# %% [markdown]
# Our train function performs the full training loop. For each epoch, it computes the training loss and accuracy, and then evaluates the model on the validation set. It returns the history of training and validation losses and accuracies for plotting later.

# %%
def train(_model, _train_loader, _val_loader, _criterion, _optimizer, _num_epochs):
    res = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': [],
    }
    iterator = tqdm(range(epochs), desc="Training", unit="epoch")

    for _ in iterator:
        _model.train()
        train_loss = 0.0
        train_acc = 0.0
        for X_batch, y_batch in _train_loader:
            _optimizer.zero_grad()
            outputs = _model(X_batch)
            loss = _criterion(outputs, y_batch)
            loss.backward()
            _optimizer.step()
            train_loss += loss.item() * X_batch.size(0)
            train_acc += get_batch_accuracy(outputs, y_batch, len(_train_loader.dataset))

        epoch_train_loss = train_loss / len(_train_loader.dataset)

        _model.eval()
        val_loss = 0.0
        val_acc = 0.0
        with torch.no_grad():
            for X_val, y_val in _val_loader:
                val_outputs = _model(X_val)
                val_loss += _criterion(val_outputs, y_val).item() * X_val.size(0)
                val_acc += get_batch_accuracy(val_outputs, y_val, len(_val_loader.dataset))

        epoch_val_loss = val_loss / len(_val_loader.dataset)

        iterator.set_postfix(
            train_loss=f"{epoch_train_loss:.4f}",
            train_acc=f"{train_acc:.4f}",
            val_loss=f"{epoch_val_loss:.4f}",
            val_acc=f"{val_acc:.4f}",
        )

        res['train_loss'].append(epoch_train_loss)
        res['train_acc'].append(train_acc)
        res['val_loss'].append(epoch_val_loss)
        res['val_acc'].append(val_acc)

    return res

# %% [markdown]
# This test function will evaluate the model on the test set after training is complete. It will calculate the average loss and accuracy across the entire test set.

# %%
def test(_model, _test_loader, _loss_function):
    _model.eval()
    test_loss = 0.0
    test_acc = 0.0
    with torch.no_grad():
        for x, y in _test_loader:
            output = _model(x)
            test_loss += _loss_function(output, y).item() * x.size(0)
            test_acc += get_batch_accuracy(output, y, len(_test_loader.dataset))

    return (test_loss / len(_test_loader.dataset)), test_acc

# %% [markdown]
# ## Training the models

# %% [markdown]
# ### Baseline model - fully connected network
#
# Before we implement the CNN, let's train a simple fully connected neural network (FCNN) as a baseline. This will help us understand the performance improvement that the CNN architecture provides for image data.

# %%
model_fcnn = nn.Sequential(
    nn.Flatten(),
    nn.Linear(IMG_HEIGHT * IMG_WIDTH, 512),
    nn.ReLU(),
    nn.Dropout(.3),

    nn.Linear(512, 512),
    nn.ReLU(),
    nn.Linear(512, 24)
)

model_fcnn = model_fcnn.to(device)

# %%
epochs = 20
loss_function = nn.CrossEntropyLoss()
optimizer = Adam(model_fcnn.parameters())

fcnn_res = train(model_fcnn, train_loader, val_loader, loss_function, optimizer, epochs)
# Out:
# Training: 100%|██████████| 20/20 [07:02<00:00, 21.11s/epoch, train_acc=0.8821, train_loss=0.3437, val_acc=0.7808, val_loss=0.8804]

# %%
fcnn_test_loss, fcnn_test_acc = test(model_fcnn, test_loader, loss_function)

# %%
# 1. Asegurar que tenemos matplotlib importado (ya lo tenías arriba, pero por si acaso)
import matplotlib.pyplot as plt

def plot_learning_curves(history):
    
    # Obtener el número de épocas basado en los datos
    epochs = range(1, len(history['train_loss']) + 1)

    # Configurar la figura (2 subgráficos lado a lado)
    plt.figure(figsize=(14, 5))

    # --- Gráfico 1: Pérdida (Loss) ---
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['train_loss'], 'b-', label='Entrenamiento')
    plt.plot(epochs, history['val_loss'], 'r-', label='Validación')
    plt.title('Curva de Pérdida (Loss)')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida (Cross Entropy)')
    plt.legend()
    plt.grid(True) # Opcional: agrega cuadrícula

    # --- Gráfico 2: Precisión (Accuracy) ---
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['train_acc'], 'b-', label='Entrenamiento')
    plt.plot(epochs, history['val_acc'], 'r-', label='Validación')
    plt.title('Curva de Precisión (Accuracy)')
    plt.xlabel('Épocas')
    plt.ylabel('Precisión (0-1)')
    # Asegurar que el eje Y cubra un rango útil si las precisiones son bajas
    # plt.ylim([0, 1]) 
    plt.legend()
    plt.grid(True)

    # Ajustar diseño para que no se superpongan los textos
    plt.tight_layout()
    plt.show()


try:
    plot_learning_curves(fcnn_res)
except KeyError as e:
    print(f"Error: La llave {e} no se encuentra en el objeto fcnn_res.")
    print("Por favor, verifica la estructura de fcnn_res (quizás sea un objeto de una librería como Ignite o Lightning).")

# %% [markdown]
# ### CNN model
#
# Now let's implement a simple CNN architecture. We will use three convolutional layers followed by max pooling, and then a couple of fully connected layers before the output layer.

# %%
model_cnn = nn.Sequential(
    nn.Conv2d(IMG_CHANNELS, 25, 3, stride=1, padding=1),  # 25 x 28 x 28
    nn.ReLU(),
    nn.MaxPool2d(2, stride=2),  # 25 x 14 x 14

    nn.Conv2d(25, 50, 3, stride=1, padding=1),  # 50 x 14 x 14
    nn.ReLU(),
    nn.Dropout(.2),
    nn.MaxPool2d(2, stride=2),  # 50 x 7 x 7

    nn.Conv2d(50, 75, 3, stride=1, padding=1),  # 75 x 7 x 7
    nn.ReLU(),
    nn.MaxPool2d(2, stride=2),  # 75 x 3 x 3

    nn.Flatten(),
    nn.Linear(75 * 3 * 3, 512),
    nn.Dropout(.3),
    nn.ReLU(),
    nn.Linear(512, 24)
)

model_cnn = model_cnn.to(device)

# %%
epochs = 20
loss_function = nn.CrossEntropyLoss()
optimizer = Adam(model_cnn.parameters())

cnn_res = train(model_cnn, train_loader, val_loader, loss_function, optimizer, epochs)
# Out:
# Training: 100%|██████████| 20/20 [14:27<00:00, 43.36s/epoch, train_acc=0.9977, train_loss=0.0075, val_acc=0.9459, val_loss=0.2856]

# %%
cnn_test_loss, cnn_test_acc = test(model_cnn, test_loader, loss_function)

# %%
import matplotlib.pyplot as plt

# --- Re-definimos la función de graficado (por si acaso no está en memoria) ---
def plot_learning_curves(history, model_name="Modelo"):
    
    # Validamos que el historial no esté vacío y tenga las llaves correctas
    if not history or 'train_loss' not in history:
        print("Error: El historial de entrenamiento está vacío o no tiene el formato correcto.")
        return

    epochs = range(1, len(history['train_loss']) + 1)

    # Configurar la figura
    plt.figure(figsize=(15, 6))
    plt.suptitle(f'Curvas de Aprendizaje - {model_name}', fontsize=16)

    # --- Gráfico 1: Pérdida (Loss) ---
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['train_loss'], 'b-o', label='Entrenamiento', markersize=4)
    plt.plot(epochs, history['val_loss'], 'r-o', label='Validación', markersize=4)
    plt.title('Pérdida (Loss Cross-Entropy)')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    # --- Gráfico 2: Precisión (Accuracy) ---
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['train_acc'], 'b-o', label='Entrenamiento', markersize=4)
    plt.plot(epochs, history['val_acc'], 'r-o', label='Validación', markersize=4)
    plt.title('Precisión (Accuracy)')
    plt.xlabel('Épocas')
    plt.ylabel('Precisión (0.0 - 1.0)')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    # Ajustar diseño
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

try:
    
    plot_learning_curves(cnn_res, model_name="CNN (Simple Architecture)")
except (TypeError, KeyError):
    
    print("cnn_res parece no ser un diccionario directo, intentando acceder a la propiedad .history...")
    try:
        plot_learning_curves(cnn_res.history, model_name="CNN (Simple Architecture)")
    except AttributeError:
        print("No se pudo extraer el historial de cnn_res automáticamente. Por favor, verifica su estructura.")

# %% [markdown]
# ## Reflection section

# %% [markdown]
# ### Which model is better at classifying ASL images?
#
# - La CNN es superior, debido a que FCNN alcanzo 78.05% de validacion
# - El CNN llego al 94.59%.
# - Debido a la forma en que extrae caracteristicas

# %% [markdown]
# ### Which model was _faster_ to train?
#
# - Fcnn fue mas rapido por epoca(21.1s vs 42.36 de CNN)
# - Pero CNN fue mas eficiente en terminos de aprendizaje.

# %% [markdown]
# ### Plot and compare the learning curves of both models. What do you observe about their training and validation performance over epochs?
#
# 1. **Velocidad de Convergencia**
# CNN: Es extremadamente agresiva.  95% de precisión en entrenamiento y la pérdida cayó casi a cero. Esto indica que los filtros convolucionales identificaron patrones espaciales muy claros casi de inmediato.
#
# FCNN: Es mucho más lenta y progresiva. Le toma casi las 20 épocas llegar a su punto máximo de precisión (~88%), lo que demuestra que le cuesta más trabajo encontrar sentido a los datos.
#
# 2. **Estabilidad de la Validación**
# CNN: Aunque es mucho más precisa (está siempre por encima del 94%), su curva de validación es más inestable . Los picos en la pérdida de validación entre las épocas 12 y 20. Esto sugiere que el modelo es muy sensible a pequeñas variaciones en las imágenes de prueba.
#
# FCNN: La curva de validación es más suave, pero se estanca rápidamente (alrededor de la época 10). No mejora después de ese punto, simplemente fluctúa en un nivel de rendimiento mediocre.
#
# 3. **Diagnóstico de Overfitting (Sobreajuste)**
# FCNN: Presenta un sobreajuste. La brecha entre las dos líneas se ensancha de forma constante y suave a medida que pasan las épocas.
#
# CNN: Muestra un sobreajuste más agudo hacia el final.La pérdida de entrenamiento es prácticamente cero absoluto, mientras que la de validación empieza a subir ligeramente después de la época 8. Esto es una señal de que el modelo está empezando a memorizar detalles irrelevantes del set de entrenamiento.

# %% [markdown]
# ### How many trainable parameters does each model have?
#
# Remember that each convolutional layer has $K \times (C_{in} \times k_h \times k_w + 1)$ parameters, where $K$ is the number of filters, $C_{in}$ is the number of input channels, $k_h$ and $k_w$ are the kernel height and width, and the +1 accounts for the bias term.
#
# Each fully connected layer has $N_{in} \times N_{out} + N_{out}$ parameters, where $N_{in}$ is the number of input features and $N_{out}$ is the number of output features.
#
# ## FCNN
# - Capa 1 784 * 512 + 512 = 401,920
# - Capa 2 512 * 512 + 512 = 262,656
# - Capa 3 512 * 24 + 24 = 12,312
# **676,888** parametros totales
#
# ## CNN
#
# - Conv1: $25 \times (1 \times 3 \times 3 + 1) = 250$
# - Conv2: $50 \times (25 \times 3 \times 3 + 1) = 11,300$
# - Conv3: $75 \times (50 \times 3 \times 3 + 1) = 33,825$
# - FC1: $(75 \times 3 \times 3) \times 512 + 512 = 346,112$
# - FC2: $512 \times 24 + 24 = 12,312$
# **403,799** parametros totales

# %% [markdown]
# ### How do the models compare in terms of overfitting? Why do you think that is the case?
#
# - Ambos modelos presentan overfitting, pero en FCNN es del 10% mientras que CNN 5%.
# - FCNN intenta memorizar pixeles espeficicos, mientras que CNN usa **dropout** y capas de **MaxPool** por lo tanto aprende nuevos patrones generales.

# %% [markdown]
# ### Final conclusions and remarks
#
# La arquitectura CNN no solo es mas precisa, sino que es mas eficiente al momento de manejar los parametros. Demostrando que en el ambito de procesamiento de imagenes, la estructura importa mas que el tamaño de la misma.
